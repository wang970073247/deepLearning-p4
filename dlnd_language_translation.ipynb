# %% [markdown]
# # 语言翻译
#
# 在此项目中，你将了解神经网络机器翻译这一领域。你将用由英语和法语语句组成的数据集，训练一个序列到序列模型（sequence to sequence model），该模型能够将新的英语句子翻译成法语。
#
# ## 获取数据
#
# 因为将整个英语语言内容翻译成法语需要大量训练时间，所以我们提供了一小部分的英语语料库。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## 探索数据
#
# 研究 view_sentence_range，查看并熟悉该数据的不同部分。

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## 实现预处理函数
#
# ### 文本到单词 id
#
# 和之前的 RNN 一样，你必须首先将文本转换为数字，这样计算机才能读懂。在函数 `text_to_ids()` 中，你需要将单词中的 `source_text` 和 `target_text` 转为 id。但是，你需要在 `target_text` 中每个句子的末尾，添加 `<EOS>` 单词 id。这样可以帮助神经网络预测句子应该在什么地方结束。
#
#
# 你可以通过以下代码获取  `<EOS> ` 单词ID：
#
# ```python
# target_vocab_to_int['<EOS>']
# ```
#
# 你可以使用 `source_vocab_to_int` 和 `target_vocab_to_int` 获得其他单词 id。

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_id_text = []
    target_id_text = []
    sentences_source = source_text.split('\n')
    sentences_target = target_text.split('\n')
    
    for sentence in sentences_source:
        id_each_text = [source_vocab_to_int[word] for word in sentence.split()]
        source_id_text.append(id_each_text)
    for sentence in sentences_target:
        id_each_text = [target_vocab_to_int[word] for word in sentence.split()]
        id_each_text.append(target_vocab_to_int['<EOS>'])
        target_id_text.append(id_each_text)

    return (source_id_text, target_id_text)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### 预处理所有数据并保存
#
# 运行以下代码单元，预处理所有数据，并保存到文件中。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，可以从这里继续。预处理的数据已保存到磁盘上。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### 检查 TensorFlow 版本，确认可访问 GPU
#
# 这一检查步骤，可以确保你使用的是正确版本的 TensorFlow，并且能够访问 GPU。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## 构建神经网络
#
# 你将通过实现以下函数，构建出要构建一个序列到序列模型所需的组件：
#
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### 输入
#
# 实现 `model_inputs()` 函数，为神经网络创建 TF 占位符。该函数应该创建以下占位符：
#
# - 名为 “input” 的输入文本占位符，并使用 TF Placeholder 名称参数（等级（Rank）为 2）。
# - 目标占位符（等级为 2）。
# - 学习速率占位符（等级为 0）。
# - 名为 “keep_prob” 的保留率占位符，并使用 TF Placeholder 名称参数（等级为 0）。
#
# 在以下元祖（tuple）中返回占位符：（输入、目标、学习速率、保留率）

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, shape=(None, None), name='input')
    targets = tf.placeholder(tf.int32, shape=(None, None), name='target')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    return inputs, targets, learning_rate, keep_prob

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### 处理解码输入
#
# 使用 TensorFlow 实现 `process_decoding_input`，以便删掉 `target_data` 中每个批次的最后一个单词 ID，并将 GO ID 放到每个批次的开头。

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for dencoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    cut_last_one = tf.strided_slice(target_data, [0,0], [batch_size,-1],[1,1])
    go = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    preprocessed_input = tf.concat([go, cut_last_one], 1)
    return preprocessed_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### 编码
#
# 实现 `encoding_layer()`，以使用 [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn) 创建编码器 RNN 层级。

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    # TODO: Implement Function
    lstm_cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    lstm_cell = tf.contrib.rnn.DropoutWrapper(lstm_cell, output_keep_prob = keep_prob)
    lstm_mul = tf.contrib.rnn.MultiRNNCell([lstm_cell] * num_layers)
    _, final_state = tf.nn.dynamic_rnn(lstm_mul, rnn_inputs, dtype=tf.float32)
    return final_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 训练
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建训练分对数（training logits）。将 `output_fn` 应用到 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 输出上。

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    # TODO: Implement Function
    train_decoder = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell,
                                                             train_decoder,
                                                             dec_embed_input,
                                                             sequence_length,
                                                             scope=decoding_scope)
    train_logits = output_fn(train_pred)
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### 解码 - 推论
#
# 使用 [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) 和 [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) 创建推论分对数（inference logits）。

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    # TODO: Implement Function
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(output_fn, encoder_state, dec_embeddings,
                                                                     start_of_sequence_id, end_of_sequence_id,
                                                                     maximum_length, vocab_size)
    infer_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(dec_cell, infer_decoder_fn, scope=decoding_scope)
    return infer_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建解码层级
#
# 实现 `decoding_layer()` 以创建解码器 RNN 层级。
#
# - 使用 `rnn_size` 和 `num_layers` 创建解码 RNN 单元。
# - 使用 [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) 创建输出函数，将输入，也就是分对数转换为类分对数（class logits）。
# - 使用 `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` 函数获取训练分对数。
# - 使用 `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` 函数获取推论分对数。
#
# 注意：你将需要使用 [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 在训练和推论分对数间分享变量。

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    lstm_cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
    mul_rnn_cell = tf.contrib.rnn.MultiRNNCell([lstm_cell] * num_layers)
    dec_cell = tf.contrib.rnn.DropoutWrapper(mul_rnn_cell, keep_prob)
    
    with tf.variable_scope("decoding") as decoding_scope:
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
        train_logits = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                                           output_fn, keep_prob)
    
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:
        start_of_sequence_id = target_vocab_to_int['<GO>']
        end_of_sequence_id = target_vocab_to_int['<EOS>']
        inference_logits = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings,
                                                start_of_sequence_id, end_of_sequence_id, sequence_length - 1, vocab_size,
                                                decoding_scope, output_fn, keep_prob)
    return train_logits, inference_logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### 构建神经网络
#
# 应用你在上方实现的函数，以：
#
# - 向编码器的输入数据应用嵌入。
# - 使用 `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)` 编码输入。
# - 使用 `process_decoding_input(target_data, target_vocab_to_int, batch_size)` 函数处理目标数据。
# - 向解码器的目标数据应用嵌入。
# - 使用 `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)` 解码编码的输入数据。

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    enc_embed_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    encoding_state = encoding_layer(enc_embed_input, rnn_size, num_layers, keep_prob)
    
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    training_logits, inference_logits = decoding_layer(dec_embed_input, dec_embeddings, encoding_state, target_vocab_size,
                   sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)
    return training_logits, inference_logits

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## 训练神经网络
#
# ### 超参数
#
# 调试以下参数：
#
# - 将 `epochs` 设为 epoch 次数。
# - 将 `batch_size` 设为批次大小。
# - 将 `rnn_size` 设为 RNN 的大小。
# - 将 `num_layers` 设为层级数量。
# - 将 `encoding_embedding_size` 设为编码器嵌入大小。
# - 将 `decoding_embedding_size` 设为解码器嵌入大小
# - 将 `learning_rate` 设为训练速率。
# - 将 `keep_probability` 设为丢弃保留率（Dropout keep probability）。

# %%
# Number of Epochs
epochs = 4
# Batch Size
batch_size = 1024
# RNN Size
rnn_size = 256
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.5

# %% [markdown]
# ### 构建图表
#
# 使用你实现的神经网络构建图表。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### 训练
#
# 利用预处理的数据训练神经网络。如果很难获得低损失值，请访问我们的论坛，看看其他人是否遇到了相同的问题。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/134 - Train Accuracy:  0.267, Validation Accuracy:  0.310, Loss:  5.883
# Epoch   0 Batch    1/134 - Train Accuracy:  0.268, Validation Accuracy:  0.336, Loss:  4.416
# Epoch   0 Batch    2/134 - Train Accuracy:  0.305, Validation Accuracy:  0.340, Loss:  4.189
# Epoch   0 Batch    3/134 - Train Accuracy:  0.312, Validation Accuracy:  0.343, Loss:  3.749
# Epoch   0 Batch    4/134 - Train Accuracy:  0.304, Validation Accuracy:  0.343, Loss:  3.542
# Epoch   0 Batch    5/134 - Train Accuracy:  0.319, Validation Accuracy:  0.349, Loss:  3.483
# Epoch   0 Batch    6/134 - Train Accuracy:  0.343, Validation Accuracy:  0.345, Loss:  3.182
# Epoch   0 Batch    7/134 - Train Accuracy:  0.301, Validation Accuracy:  0.338, Loss:  3.480
# Epoch   0 Batch    8/134 - Train Accuracy:  0.308, Validation Accuracy:  0.348, Loss:  3.358
# Epoch   0 Batch    9/134 - Train Accuracy:  0.340, Validation Accuracy:  0.343, Loss:  3.134
# Epoch   0 Batch   10/134 - Train Accuracy:  0.315, Validation Accuracy:  0.345, Loss:  3.233
# Epoch   0 Batch   11/134 - Train Accuracy:  0.324, Validation Accuracy:  0.350, Loss:  3.168
# Epoch   0 Batch   12/134 - Train Accuracy:  0.353, Validation Accuracy:  0.354, Loss:  2.996
# Epoch   0 Batch   13/134 - Train Accuracy:  0.318, Validation Accuracy:  0.358, Loss:  3.100
# Epoch   0 Batch   14/134 - Train Accuracy:  0.329, Validation Accuracy:  0.365, Loss:  3.028
# Epoch   0 Batch   15/134 - Train Accuracy:  0.353, Validation Accuracy:  0.385, Loss:  3.035
# Epoch   0 Batch   16/134 - Train Accuracy:  0.353, Validation Accuracy:  0.384, Loss:  2.925
# Epoch   0 Batch   17/134 - Train Accuracy:  0.355, Validation Accuracy:  0.385, Loss:  2.908
# Epoch   0 Batch   18/134 - Train Accuracy:  0.357, Validation Accuracy:  0.387, Loss:  2.919
# Epoch   0 Batch   19/134 - Train Accuracy:  0.354, Validation Accuracy:  0.386, Loss:  2.809
# Epoch   0 Batch   20/134 - Train Accuracy:  0.382, Validation Accuracy:  0.385, Loss:  2.684
# Epoch   0 Batch   21/134 - Train Accuracy:  0.363, Validation Accuracy:  0.388, Loss:  2.829
# Epoch   0 Batch   22/134 - Train Accuracy:  0.321, Validation Accuracy:  0.385, Loss:  2.890
# Epoch   0 Batch   23/134 - Train Accuracy:  0.399, Validation Accuracy:  0.398, Loss:  2.582
# Epoch   0 Batch   24/134 - Train Accuracy:  0.339, Validation Accuracy:  0.396, Loss:  2.825
# Epoch   0 Batch   25/134 - Train Accuracy:  0.393, Validation Accuracy:  0.425, Loss:  2.665
# Epoch   0 Batch   26/134 - Train Accuracy:  0.365, Validation Accuracy:  0.422, Loss:  2.748
# Epoch   0 Batch   27/134 - Train Accuracy:  0.390, Validation Accuracy:  0.416, Loss:  2.594
# Epoch   0 Batch   28/134 - Train Accuracy:  0.394, Validation Accuracy:  0.420, Loss:  2.570
# Epoch   0 Batch   29/134 - Train Accuracy:  0.422, Validation Accuracy:  0.431, Loss:  2.460
# Epoch   0 Batch   30/134 - Train Accuracy:  0.444, Validation Accuracy:  0.446, Loss:  2.421
# Epoch   0 Batch   31/134 - Train Accuracy:  0.425, Validation Accuracy:  0.454, Loss:  2.484
# Epoch   0 Batch   32/134 - Train Accuracy:  0.447, Validation Accuracy:  0.453, Loss:  2.377
# Epoch   0 Batch   33/134 - Train Accuracy:  0.417, Validation Accuracy:  0.448, Loss:  2.441
# Epoch   0 Batch   34/134 - Train Accuracy:  0.436, Validation Accuracy:  0.460, Loss:  2.427
# Epoch   0 Batch   35/134 - Train Accuracy:  0.460, Validation Accuracy:  0.468, Loss:  2.295
# Epoch   0 Batch   36/134 - Train Accuracy:  0.452, Validation Accuracy:  0.475, Loss:  2.346
# Epoch   0 Batch   37/134 - Train Accuracy:  0.440, Validation Accuracy:  0.472, Loss:  2.363
# Epoch   0 Batch   38/134 - Train Accuracy:  0.439, Validation Accuracy:  0.466, Loss:  2.301
# Epoch   0 Batch   39/134 - Train Accuracy:  0.453, Validation Accuracy:  0.478, Loss:  2.268
# Epoch   0 Batch   40/134 - Train Accuracy:  0.457, Validation Accuracy:  0.479, Loss:  2.242
# Epoch   0 Batch   41/134 - Train Accuracy:  0.455, Validation Accuracy:  0.481, Loss:  2.214
# Epoch   0 Batch   42/134 - Train Accuracy:  0.461, Validation Accuracy:  0.496, Loss:  2.233
# Epoch   0 Batch   43/134 - Train Accuracy:  0.460, Validation Accuracy:  0.491, Loss:  2.201
# Epoch   0 Batch   44/134 - Train Accuracy:  0.482, Validation Accuracy:  0.511, Loss:  2.170
# Epoch   0 Batch   45/134 - Train Accuracy:  0.491, Validation Accuracy:  0.520, Loss:  2.138
# Epoch   0 Batch   46/134 - Train Accuracy:  0.496, Validation Accuracy:  0.498, Loss:  2.047
# Epoch   0 Batch   47/134 - Train Accuracy:  0.487, Validation Accuracy:  0.513, Loss:  2.107
# Epoch   0 Batch   48/134 - Train Accuracy:  0.498, Validation Accuracy:  0.516, Loss:  2.058
# Epoch   0 Batch   49/134 - Train Accuracy:  0.496, Validation Accuracy:  0.517, Loss:  2.037
# Epoch   0 Batch   50/134 - Train Accuracy:  0.495, Validation Accuracy:  0.525, Loss:  2.043
# Epoch   0 Batch   51/134 - Train Accuracy:  0.498, Validation Accuracy:  0.528, Loss:  2.023
# Epoch   0 Batch   52/134 - Train Accuracy:  0.506, Validation Accuracy:  0.536, Loss:  2.020
# Epoch   0 Batch   53/134 - Train Accuracy:  0.479, Validation Accuracy:  0.516, Loss:  2.006
# Epoch   0 Batch   54/134 - Train Accuracy:  0.487, Validation Accuracy:  0.522, Loss:  1.995
# Epoch   0 Batch   55/134 - Train Accuracy:  0.470, Validation Accuracy:  0.498, Loss:  2.027
# Epoch   0 Batch   56/134 - Train Accuracy:  0.526, Validation Accuracy:  0.540, Loss:  1.909
# Epoch   0 Batch   57/134 - Train Accuracy:  0.494, Validation Accuracy:  0.522, Loss:  1.914
# Epoch   0 Batch   58/134 - Train Accuracy:  0.494, Validation Accuracy:  0.520, Loss:  1.924
# Epoch   0 Batch   59/134 - Train Accuracy:  0.500, Validation Accuracy:  0.544, Loss:  1.999
# Epoch   0 Batch   60/134 - Train Accuracy:  0.529, Validation Accuracy:  0.552, Loss:  1.887
# Epoch   0 Batch   61/134 - Train Accuracy:  0.506, Validation Accuracy:  0.534, Loss:  1.871
# Epoch   0 Batch   62/134 - Train Accuracy:  0.508, Validation Accuracy:  0.529, Loss:  1.848
# Epoch   0 Batch   63/134 - Train Accuracy:  0.525, Validation Accuracy:  0.544, Loss:  1.819
# Epoch   0 Batch   64/134 - Train Accuracy:  0.493, Validation Accuracy:  0.526, Loss:  1.836
# Epoch   0 Batch   65/134 - Train Accuracy:  0.519, Validation Accuracy:  0.548, Loss:  1.818
# Epoch   0 Batch   66/134 - Train Accuracy:  0.518, Validation Accuracy:  0.546, Loss:  1.750
# Epoch   0 Batch   67/134 - Train Accuracy:  0.500, Validation Accuracy:  0.552, Loss:  1.852
# Epoch   0 Batch   68/134 - Train Accuracy:  0.500, Validation Accuracy:  0.542, Loss:  1.768
# Epoch   0 Batch   69/134 - Train Accuracy:  0.539, Validation Accuracy:  0.553, Loss:  1.687
# Epoch   0 Batch   70/134 - Train Accuracy:  0.538, Validation Accuracy:  0.554, Loss:  1.627
# Epoch   0 Batch   71/134 - Train Accuracy:  0.532, Validation Accuracy:  0.555, Loss:  1.626
# Epoch   0 Batch   72/134 - Train Accuracy:  0.537, Validation Accuracy:  0.560, Loss:  1.602
# Epoch   0 Batch   73/134 - Train Accuracy:  0.543, Validation Accuracy:  0.551, Loss:  1.552
# Epoch   0 Batch   74/134 - Train Accuracy:  0.538, Validation Accuracy:  0.561, Loss:  1.565
# Epoch   0 Batch   75/134 - Train Accuracy:  0.565, Validation Accuracy:  0.562, Loss:  1.454
# Epoch   0 Batch   76/134 - Train Accuracy:  0.530, Validation Accuracy:  0.559, Loss:  1.503
# Epoch   0 Batch   77/134 - Train Accuracy:  0.574, Validation Accuracy:  0.568, Loss:  1.410
# Epoch   0 Batch   78/134 - Train Accuracy:  0.510, Validation Accuracy:  0.538, Loss:  1.473
# Epoch   0 Batch   79/134 - Train Accuracy:  0.543, Validation Accuracy:  0.567, Loss:  1.458
# Epoch   0 Batch   80/134 - Train Accuracy:  0.529, Validation Accuracy:  0.559, Loss:  1.425
# Epoch   0 Batch   81/134 - Train Accuracy:  0.539, Validation Accuracy:  0.556, Loss:  1.389
# Epoch   0 Batch   82/134 - Train Accuracy:  0.541, Validation Accuracy:  0.550, Loss:  1.293
# Epoch   0 Batch   83/134 - Train Accuracy:  0.549, Validation Accuracy:  0.570, Loss:  1.355
# Epoch   0 Batch   84/134 - Train Accuracy:  0.534, Validation Accuracy:  0.564, Loss:  1.324
# Epoch   0 Batch   85/134 - Train Accuracy:  0.526, Validation Accuracy:  0.548, Loss:  1.303
# Epoch   0 Batch   86/134 - Train Accuracy:  0.520, Validation Accuracy:  0.545, Loss:  1.288
# Epoch   0 Batch   87/134 - Train Accuracy:  0.536, Validation Accuracy:  0.561, Loss:  1.271
# Epoch   0 Batch   88/134 - Train Accuracy:  0.541, Validation Accuracy:  0.546, Loss:  1.191
# Epoch   0 Batch   89/134 - Train Accuracy:  0.525, Validation Accuracy:  0.550, Loss:  1.209
# Epoch   0 Batch   90/134 - Train Accuracy:  0.517, Validation Accuracy:  0.546, Loss:  1.207
# Epoch   0 Batch   91/134 - Train Accuracy:  0.584, Validation Accuracy:  0.545, Loss:  1.043
# Epoch   0 Batch   92/134 - Train Accuracy:  0.501, Validation Accuracy:  0.522, Loss:  1.181
# Epoch   0 Batch   93/134 - Train Accuracy:  0.487, Validation Accuracy:  0.503, Loss:  1.174
# Epoch   0 Batch   94/134 - Train Accuracy:  0.523, Validation Accuracy:  0.548, Loss:  1.157
# Epoch   0 Batch   95/134 - Train Accuracy:  0.511, Validation Accuracy:  0.532, Loss:  1.130
# Epoch   0 Batch   96/134 - Train Accuracy:  0.516, Validation Accuracy:  0.537, Loss:  1.107
# Epoch   0 Batch   97/134 - Train Accuracy:  0.506, Validation Accuracy:  0.537, Loss:  1.093
# Epoch   0 Batch   98/134 - Train Accuracy:  0.480, Validation Accuracy:  0.535, Loss:  1.125
# Epoch   0 Batch   99/134 - Train Accuracy:  0.528, Validation Accuracy:  0.553, Loss:  1.071
# Epoch   0 Batch  100/134 - Train Accuracy:  0.512, Validation Accuracy:  0.540, Loss:  1.041
# Epoch   0 Batch  101/134 - Train Accuracy:  0.491, Validation Accuracy:  0.538, Loss:  1.070
# Epoch   0 Batch  102/134 - Train Accuracy:  0.509, Validation Accuracy:  0.534, Loss:  1.004
# Epoch   0 Batch  103/134 - Train Accuracy:  0.531, Validation Accuracy:  0.535, Loss:  0.964
# Epoch   0 Batch  104/134 - Train Accuracy:  0.524, Validation Accuracy:  0.545, Loss:  0.963
# Epoch   0 Batch  105/134 - Train Accuracy:  0.550, Validation Accuracy:  0.564, Loss:  0.961
# Epoch   0 Batch  106/134 - Train Accuracy:  0.554, Validation Accuracy:  0.565, Loss:  0.942
# Epoch   0 Batch  107/134 - Train Accuracy:  0.563, Validation Accuracy:  0.570, Loss:  0.895
# Epoch   0 Batch  108/134 - Train Accuracy:  0.534, Validation Accuracy:  0.575, Loss:  0.972
# Epoch   0 Batch  109/134 - Train Accuracy:  0.573, Validation Accuracy:  0.578, Loss:  0.870
# Epoch   0 Batch  110/134 - Train Accuracy:  0.553, Validation Accuracy:  0.567, Loss:  0.888
# Epoch   0 Batch  111/134 - Train Accuracy:  0.550, Validation Accuracy:  0.563, Loss:  0.898
# Epoch   0 Batch  112/134 - Train Accuracy:  0.548, Validation Accuracy:  0.564, Loss:  0.873
# Epoch   0 Batch  113/134 - Train Accuracy:  0.598, Validation Accuracy:  0.565, Loss:  0.769
# Epoch   0 Batch  114/134 - Train Accuracy:  0.542, Validation Accuracy:  0.567, Loss:  0.868
# Epoch   0 Batch  115/134 - Train Accuracy:  0.519, Validation Accuracy:  0.571, Loss:  0.904
# Epoch   0 Batch  116/134 - Train Accuracy:  0.549, Validation Accuracy:  0.574, Loss:  0.849
# Epoch   0 Batch  117/134 - Train Accuracy:  0.557, Validation Accuracy:  0.579, Loss:  0.833
# Epoch   0 Batch  118/134 - Train Accuracy:  0.552, Validation Accuracy:  0.575, Loss:  0.824
# Epoch   0 Batch  119/134 - Train Accuracy:  0.596, Validation Accuracy:  0.579, Loss:  0.756
# Epoch   0 Batch  120/134 - Train Accuracy:  0.562, Validation Accuracy:  0.586, Loss:  0.819
# Epoch   0 Batch  121/134 - Train Accuracy:  0.572, Validation Accuracy:  0.584, Loss:  0.800
# Epoch   0 Batch  122/134 - Train Accuracy:  0.568, Validation Accuracy:  0.593, Loss:  0.805
# Epoch   0 Batch  123/134 - Train Accuracy:  0.573, Validation Accuracy:  0.596, Loss:  0.787
# Epoch   0 Batch  124/134 - Train Accuracy:  0.599, Validation Accuracy:  0.595, Loss:  0.747
# Epoch   0 Batch  125/134 - Train Accuracy:  0.575, Validation Accuracy:  0.593, Loss:  0.780
# Epoch   0 Batch  126/134 - Train Accuracy:  0.567, Validation Accuracy:  0.592, Loss:  0.780
# Epoch   0 Batch  127/134 - Train Accuracy:  0.581, Validation Accuracy:  0.587, Loss:  0.743
# Epoch   0 Batch  128/134 - Train Accuracy:  0.567, Validation Accuracy:  0.596, Loss:  0.770
# Epoch   0 Batch  129/134 - Train Accuracy:  0.591, Validation Accuracy:  0.599, Loss:  0.752
# Epoch   0 Batch  130/134 - Train Accuracy:  0.577, Validation Accuracy:  0.605, Loss:  0.753
# Epoch   0 Batch  131/134 - Train Accuracy:  0.572, Validation Accuracy:  0.602, Loss:  0.780
# Epoch   0 Batch  132/134 - Train Accuracy:  0.581, Validation Accuracy:  0.590, Loss:  0.732
# Epoch   1 Batch    0/134 - Train Accuracy:  0.567, Validation Accuracy:  0.600, Loss:  0.731
# Epoch   1 Batch    1/134 - Train Accuracy:  0.568, Validation Accuracy:  0.597, Loss:  0.747
# Epoch   1 Batch    2/134 - Train Accuracy:  0.577, Validation Accuracy:  0.595, Loss:  0.707
# Epoch   1 Batch    3/134 - Train Accuracy:  0.581, Validation Accuracy:  0.603, Loss:  0.714
# Epoch   1 Batch    4/134 - Train Accuracy:  0.580, Validation Accuracy:  0.604, Loss:  0.719
# Epoch   1 Batch    5/134 - Train Accuracy:  0.572, Validation Accuracy:  0.594, Loss:  0.708
# Epoch   1 Batch    6/134 - Train Accuracy:  0.599, Validation Accuracy:  0.597, Loss:  0.659
# Epoch   1 Batch    7/134 - Train Accuracy:  0.598, Validation Accuracy:  0.618, Loss:  0.691
# Epoch   1 Batch    8/134 - Train Accuracy:  0.593, Validation Accuracy:  0.613, Loss:  0.676
# Epoch   1 Batch    9/134 - Train Accuracy:  0.620, Validation Accuracy:  0.610, Loss:  0.645
# Epoch   1 Batch   10/134 - Train Accuracy:  0.605, Validation Accuracy:  0.616, Loss:  0.679
# Epoch   1 Batch   11/134 - Train Accuracy:  0.612, Validation Accuracy:  0.621, Loss:  0.674
# Epoch   1 Batch   12/134 - Train Accuracy:  0.626, Validation Accuracy:  0.617, Loss:  0.640
# Epoch   1 Batch   13/134 - Train Accuracy:  0.585, Validation Accuracy:  0.622, Loss:  0.674
# Epoch   1 Batch   14/134 - Train Accuracy:  0.612, Validation Accuracy:  0.623, Loss:  0.659
# Epoch   1 Batch   15/134 - Train Accuracy:  0.611, Validation Accuracy:  0.625, Loss:  0.644
# Epoch   1 Batch   16/134 - Train Accuracy:  0.618, Validation Accuracy:  0.624, Loss:  0.640
# Epoch   1 Batch   17/134 - Train Accuracy:  0.616, Validation Accuracy:  0.623, Loss:  0.655
# Epoch   1 Batch   18/134 - Train Accuracy:  0.609, Validation Accuracy:  0.621, Loss:  0.644
# Epoch   1 Batch   19/134 - Train Accuracy:  0.608, Validation Accuracy:  0.618, Loss:  0.646
# Epoch   1 Batch   20/134 - Train Accuracy:  0.633, Validation Accuracy:  0.623, Loss:  0.616
# Epoch   1 Batch   21/134 - Train Accuracy:  0.624, Validation Accuracy:  0.629, Loss:  0.627
# Epoch   1 Batch   22/134 - Train Accuracy:  0.597, Validation Accuracy:  0.624, Loss:  0.661
# Epoch   1 Batch   23/134 - Train Accuracy:  0.635, Validation Accuracy:  0.625, Loss:  0.593
# Epoch   1 Batch   24/134 - Train Accuracy:  0.600, Validation Accuracy:  0.625, Loss:  0.647
# Epoch   1 Batch   25/134 - Train Accuracy:  0.601, Validation Accuracy:  0.622, Loss:  0.609
# Epoch   1 Batch   26/134 - Train Accuracy:  0.604, Validation Accuracy:  0.628, Loss:  0.646
# Epoch   1 Batch   27/134 - Train Accuracy:  0.630, Validation Accuracy:  0.633, Loss:  0.609
# Epoch   1 Batch   28/134 - Train Accuracy:  0.625, Validation Accuracy:  0.622, Loss:  0.610
# Epoch   1 Batch   29/134 - Train Accuracy:  0.621, Validation Accuracy:  0.616, Loss:  0.577
# Epoch   1 Batch   30/134 - Train Accuracy:  0.616, Validation Accuracy:  0.619, Loss:  0.586
# Epoch   1 Batch   31/134 - Train Accuracy:  0.569, Validation Accuracy:  0.600, Loss:  0.637
# Epoch   1 Batch   32/134 - Train Accuracy:  0.548, Validation Accuracy:  0.547, Loss:  0.685
# Epoch   1 Batch   33/134 - Train Accuracy:  0.555, Validation Accuracy:  0.573, Loss:  0.803
# Epoch   1 Batch   34/134 - Train Accuracy:  0.559, Validation Accuracy:  0.568, Loss:  0.704
# Epoch   1 Batch   35/134 - Train Accuracy:  0.571, Validation Accuracy:  0.574, Loss:  0.652
# Epoch   1 Batch   36/134 - Train Accuracy:  0.596, Validation Accuracy:  0.597, Loss:  0.659
# Epoch   1 Batch   37/134 - Train Accuracy:  0.576, Validation Accuracy:  0.590, Loss:  0.658
# Epoch   1 Batch   38/134 - Train Accuracy:  0.594, Validation Accuracy:  0.589, Loss:  0.640
# Epoch   1 Batch   39/134 - Train Accuracy:  0.600, Validation Accuracy:  0.608, Loss:  0.634
# Epoch   1 Batch   40/134 - Train Accuracy:  0.607, Validation Accuracy:  0.601, Loss:  0.620
# Epoch   1 Batch   41/134 - Train Accuracy:  0.604, Validation Accuracy:  0.607, Loss:  0.627
# Epoch   1 Batch   42/134 - Train Accuracy:  0.596, Validation Accuracy:  0.605, Loss:  0.616
# Epoch   1 Batch   43/134 - Train Accuracy:  0.594, Validation Accuracy:  0.606, Loss:  0.619
# Epoch   1 Batch   44/134 - Train Accuracy:  0.609, Validation Accuracy:  0.618, Loss:  0.602
# Epoch   1 Batch   45/134 - Train Accuracy:  0.613, Validation Accuracy:  0.626, Loss:  0.592
# Epoch   1 Batch   46/134 - Train Accuracy:  0.632, Validation Accuracy:  0.633, Loss:  0.573
# Epoch   1 Batch   47/134 - Train Accuracy:  0.608, Validation Accuracy:  0.619, Loss:  0.588
# Epoch   1 Batch   48/134 - Train Accuracy:  0.613, Validation Accuracy:  0.623, Loss:  0.580
# Epoch   1 Batch   49/134 - Train Accuracy:  0.622, Validation Accuracy:  0.629, Loss:  0.574
# Epoch   1 Batch   50/134 - Train Accuracy:  0.613, Validation Accuracy:  0.630, Loss:  0.575
# Epoch   1 Batch   51/134 - Train Accuracy:  0.611, Validation Accuracy:  0.633, Loss:  0.568
# Epoch   1 Batch   52/134 - Train Accuracy:  0.614, Validation Accuracy:  0.634, Loss:  0.569
# Epoch   1 Batch   53/134 - Train Accuracy:  0.616, Validation Accuracy:  0.627, Loss:  0.564
# Epoch   1 Batch   54/134 - Train Accuracy:  0.621, Validation Accuracy:  0.630, Loss:  0.554
# Epoch   1 Batch   55/134 - Train Accuracy:  0.623, Validation Accuracy:  0.637, Loss:  0.552
# Epoch   1 Batch   56/134 - Train Accuracy:  0.628, Validation Accuracy:  0.631, Loss:  0.523
# Epoch   1 Batch   57/134 - Train Accuracy:  0.633, Validation Accuracy:  0.639, Loss:  0.547
# Epoch   1 Batch   58/134 - Train Accuracy:  0.644, Validation Accuracy:  0.652, Loss:  0.538
# Epoch   1 Batch   59/134 - Train Accuracy:  0.625, Validation Accuracy:  0.649, Loss:  0.559
# Epoch   1 Batch   60/134 - Train Accuracy:  0.642, Validation Accuracy:  0.647, Loss:  0.526
# Epoch   1 Batch   61/134 - Train Accuracy:  0.641, Validation Accuracy:  0.645, Loss:  0.527
# Epoch   1 Batch   62/134 - Train Accuracy:  0.630, Validation Accuracy:  0.641, Loss:  0.528
# Epoch   1 Batch   63/134 - Train Accuracy:  0.639, Validation Accuracy:  0.644, Loss:  0.519
# Epoch   1 Batch   64/134 - Train Accuracy:  0.637, Validation Accuracy:  0.653, Loss:  0.518
# Epoch   1 Batch   65/134 - Train Accuracy:  0.640, Validation Accuracy:  0.658, Loss:  0.521
# Epoch   1 Batch   66/134 - Train Accuracy:  0.642, Validation Accuracy:  0.653, Loss:  0.507
# Epoch   1 Batch   67/134 - Train Accuracy:  0.625, Validation Accuracy:  0.660, Loss:  0.552
# Epoch   1 Batch   68/134 - Train Accuracy:  0.643, Validation Accuracy:  0.664, Loss:  0.530
# Epoch   1 Batch   69/134 - Train Accuracy:  0.655, Validation Accuracy:  0.664, Loss:  0.506
# Epoch   1 Batch   70/134 - Train Accuracy:  0.659, Validation Accuracy:  0.662, Loss:  0.497
# Epoch   1 Batch   71/134 - Train Accuracy:  0.647, Validation Accuracy:  0.661, Loss:  0.493
# Epoch   1 Batch   72/134 - Train Accuracy:  0.645, Validation Accuracy:  0.657, Loss:  0.494
# Epoch   1 Batch   73/134 - Train Accuracy:  0.663, Validation Accuracy:  0.658, Loss:  0.474
# Epoch   1 Batch   74/134 - Train Accuracy:  0.653, Validation Accuracy:  0.665, Loss:  0.491
# Epoch   1 Batch   75/134 - Train Accuracy:  0.681, Validation Accuracy:  0.668, Loss:  0.466
# Epoch   1 Batch   76/134 - Train Accuracy:  0.656, Validation Accuracy:  0.667, Loss:  0.484
# Epoch   1 Batch   77/134 - Train Accuracy:  0.670, Validation Accuracy:  0.664, Loss:  0.464
# Epoch   1 Batch   78/134 - Train Accuracy:  0.658, Validation Accuracy:  0.667, Loss:  0.484
# Epoch   1 Batch   79/134 - Train Accuracy:  0.660, Validation Accuracy:  0.674, Loss:  0.475
# Epoch   1 Batch   80/134 - Train Accuracy:  0.664, Validation Accuracy:  0.671, Loss:  0.474
# Epoch   1 Batch   81/134 - Train Accuracy:  0.661, Validation Accuracy:  0.669, Loss:  0.474
# Epoch   1 Batch   82/134 - Train Accuracy:  0.669, Validation Accuracy:  0.667, Loss:  0.443
# Epoch   1 Batch   83/134 - Train Accuracy:  0.669, Validation Accuracy:  0.674, Loss:  0.469
# Epoch   1 Batch   84/134 - Train Accuracy:  0.658, Validation Accuracy:  0.674, Loss:  0.465
# Epoch   1 Batch   85/134 - Train Accuracy:  0.665, Validation Accuracy:  0.668, Loss:  0.468
# Epoch   1 Batch   86/134 - Train Accuracy:  0.647, Validation Accuracy:  0.673, Loss:  0.455
# Epoch   1 Batch   87/134 - Train Accuracy:  0.663, Validation Accuracy:  0.673, Loss:  0.469
# Epoch   1 Batch   88/134 - Train Accuracy:  0.680, Validation Accuracy:  0.676, Loss:  0.431
# Epoch   1 Batch   89/134 - Train Accuracy:  0.661, Validation Accuracy:  0.673, Loss:  0.451
# Epoch   1 Batch   90/134 - Train Accuracy:  0.664, Validation Accuracy:  0.672, Loss:  0.450
# Epoch   1 Batch   91/134 - Train Accuracy:  0.720, Validation Accuracy:  0.679, Loss:  0.394
# Epoch   1 Batch   92/134 - Train Accuracy:  0.672, Validation Accuracy:  0.681, Loss:  0.440
# Epoch   1 Batch   93/134 - Train Accuracy:  0.674, Validation Accuracy:  0.683, Loss:  0.430
# Epoch   1 Batch   94/134 - Train Accuracy:  0.669, Validation Accuracy:  0.682, Loss:  0.433
# Epoch   1 Batch   95/134 - Train Accuracy:  0.677, Validation Accuracy:  0.683, Loss:  0.439
# Epoch   1 Batch   96/134 - Train Accuracy:  0.672, Validation Accuracy:  0.681, Loss:  0.440
# Epoch   1 Batch   97/134 - Train Accuracy:  0.664, Validation Accuracy:  0.683, Loss:  0.432
# Epoch   1 Batch   98/134 - Train Accuracy:  0.646, Validation Accuracy:  0.683, Loss:  0.456
# Epoch   1 Batch   99/134 - Train Accuracy:  0.676, Validation Accuracy:  0.687, Loss:  0.434
# Epoch   1 Batch  100/134 - Train Accuracy:  0.676, Validation Accuracy:  0.686, Loss:  0.425
# Epoch   1 Batch  101/134 - Train Accuracy:  0.665, Validation Accuracy:  0.690, Loss:  0.449
# Epoch   1 Batch  102/134 - Train Accuracy:  0.684, Validation Accuracy:  0.688, Loss:  0.422
# Epoch   1 Batch  103/134 - Train Accuracy:  0.686, Validation Accuracy:  0.684, Loss:  0.403
# Epoch   1 Batch  104/134 - Train Accuracy:  0.692, Validation Accuracy:  0.689, Loss:  0.412
# Epoch   1 Batch  105/134 - Train Accuracy:  0.689, Validation Accuracy:  0.694, Loss:  0.420
# Epoch   1 Batch  106/134 - Train Accuracy:  0.685, Validation Accuracy:  0.695, Loss:  0.417
# Epoch   1 Batch  107/134 - Train Accuracy:  0.703, Validation Accuracy:  0.698, Loss:  0.395
# Epoch   1 Batch  108/134 - Train Accuracy:  0.663, Validation Accuracy:  0.689, Loss:  0.428
# Epoch   1 Batch  109/134 - Train Accuracy:  0.690, Validation Accuracy:  0.686, Loss:  0.385
# Epoch   1 Batch  110/134 - Train Accuracy:  0.706, Validation Accuracy:  0.696, Loss:  0.398
# Epoch   1 Batch  111/134 - Train Accuracy:  0.698, Validation Accuracy:  0.700, Loss:  0.404
# Epoch   1 Batch  112/134 - Train Accuracy:  0.695, Validation Accuracy:  0.695, Loss:  0.392
# Epoch   1 Batch  113/134 - Train Accuracy:  0.733, Validation Accuracy:  0.699, Loss:  0.351
# Epoch   1 Batch  114/134 - Train Accuracy:  0.692, Validation Accuracy:  0.702, Loss:  0.392
# Epoch   1 Batch  115/134 - Train Accuracy:  0.653, Validation Accuracy:  0.697, Loss:  0.417
# Epoch   1 Batch  116/134 - Train Accuracy:  0.706, Validation Accuracy:  0.708, Loss:  0.393
# Epoch   1 Batch  117/134 - Train Accuracy:  0.696, Validation Accuracy:  0.708, Loss:  0.383
# Epoch   1 Batch  118/134 - Train Accuracy:  0.697, Validation Accuracy:  0.704, Loss:  0.383
# Epoch   1 Batch  119/134 - Train Accuracy:  0.724, Validation Accuracy:  0.705, Loss:  0.349
# Epoch   1 Batch  120/134 - Train Accuracy:  0.694, Validation Accuracy:  0.696, Loss:  0.385
# Epoch   1 Batch  121/134 - Train Accuracy:  0.718, Validation Accuracy:  0.715, Loss:  0.378
# Epoch   1 Batch  122/134 - Train Accuracy:  0.700, Validation Accuracy:  0.717, Loss:  0.378
# Epoch   1 Batch  123/134 - Train Accuracy:  0.712, Validation Accuracy:  0.713, Loss:  0.367
# Epoch   1 Batch  124/134 - Train Accuracy:  0.744, Validation Accuracy:  0.724, Loss:  0.350
# Epoch   1 Batch  125/134 - Train Accuracy:  0.717, Validation Accuracy:  0.724, Loss:  0.367
# Epoch   1 Batch  126/134 - Train Accuracy:  0.701, Validation Accuracy:  0.719, Loss:  0.373
# Epoch   1 Batch  127/134 - Train Accuracy:  0.735, Validation Accuracy:  0.731, Loss:  0.355
# Epoch   1 Batch  128/134 - Train Accuracy:  0.720, Validation Accuracy:  0.734, Loss:  0.368
# Epoch   1 Batch  129/134 - Train Accuracy:  0.705, Validation Accuracy:  0.727, Loss:  0.361
# Epoch   1 Batch  130/134 - Train Accuracy:  0.724, Validation Accuracy:  0.731, Loss:  0.363
# Epoch   1 Batch  131/134 - Train Accuracy:  0.722, Validation Accuracy:  0.732, Loss:  0.377
# Epoch   1 Batch  132/134 - Train Accuracy:  0.722, Validation Accuracy:  0.731, Loss:  0.352
# Epoch   2 Batch    0/134 - Train Accuracy:  0.736, Validation Accuracy:  0.732, Loss:  0.349
# Epoch   2 Batch    1/134 - Train Accuracy:  0.729, Validation Accuracy:  0.739, Loss:  0.360
# Epoch   2 Batch    2/134 - Train Accuracy:  0.739, Validation Accuracy:  0.733, Loss:  0.340
# Epoch   2 Batch    3/134 - Train Accuracy:  0.740, Validation Accuracy:  0.745, Loss:  0.347
# Epoch   2 Batch    4/134 - Train Accuracy:  0.736, Validation Accuracy:  0.743, Loss:  0.348
# Epoch   2 Batch    5/134 - Train Accuracy:  0.733, Validation Accuracy:  0.738, Loss:  0.345
# Epoch   2 Batch    6/134 - Train Accuracy:  0.741, Validation Accuracy:  0.748, Loss:  0.321
# Epoch   2 Batch    7/134 - Train Accuracy:  0.736, Validation Accuracy:  0.756, Loss:  0.337
# Epoch   2 Batch    8/134 - Train Accuracy:  0.751, Validation Accuracy:  0.752, Loss:  0.329
# Epoch   2 Batch    9/134 - Train Accuracy:  0.763, Validation Accuracy:  0.754, Loss:  0.308
# Epoch   2 Batch   10/134 - Train Accuracy:  0.741, Validation Accuracy:  0.754, Loss:  0.331
# Epoch   2 Batch   11/134 - Train Accuracy:  0.748, Validation Accuracy:  0.754, Loss:  0.321
# Epoch   2 Batch   12/134 - Train Accuracy:  0.759, Validation Accuracy:  0.757, Loss:  0.311
# Epoch   2 Batch   13/134 - Train Accuracy:  0.741, Validation Accuracy:  0.756, Loss:  0.326
# Epoch   2 Batch   14/134 - Train Accuracy:  0.748, Validation Accuracy:  0.757, Loss:  0.323
# Epoch   2 Batch   15/134 - Train Accuracy:  0.744, Validation Accuracy:  0.755, Loss:  0.311
# Epoch   2 Batch   16/134 - Train Accuracy:  0.752, Validation Accuracy:  0.752, Loss:  0.312
# Epoch   2 Batch   17/134 - Train Accuracy:  0.737, Validation Accuracy:  0.754, Loss:  0.321
# Epoch   2 Batch   18/134 - Train Accuracy:  0.753, Validation Accuracy:  0.758, Loss:  0.314
# Epoch   2 Batch   19/134 - Train Accuracy:  0.754, Validation Accuracy:  0.757, Loss:  0.307
# Epoch   2 Batch   20/134 - Train Accuracy:  0.769, Validation Accuracy:  0.757, Loss:  0.297
# Epoch   2 Batch   21/134 - Train Accuracy:  0.761, Validation Accuracy:  0.757, Loss:  0.304
# Epoch   2 Batch   22/134 - Train Accuracy:  0.732, Validation Accuracy:  0.751, Loss:  0.317
# Epoch   2 Batch   23/134 - Train Accuracy:  0.773, Validation Accuracy:  0.754, Loss:  0.287
# Epoch   2 Batch   24/134 - Train Accuracy:  0.744, Validation Accuracy:  0.756, Loss:  0.309
# Epoch   2 Batch   25/134 - Train Accuracy:  0.744, Validation Accuracy:  0.756, Loss:  0.292
# Epoch   2 Batch   26/134 - Train Accuracy:  0.746, Validation Accuracy:  0.767, Loss:  0.315
# Epoch   2 Batch   27/134 - Train Accuracy:  0.762, Validation Accuracy:  0.769, Loss:  0.293
# Epoch   2 Batch   28/134 - Train Accuracy:  0.764, Validation Accuracy:  0.769, Loss:  0.296
# Epoch   2 Batch   29/134 - Train Accuracy:  0.775, Validation Accuracy:  0.764, Loss:  0.273
# Epoch   2 Batch   30/134 - Train Accuracy:  0.769, Validation Accuracy:  0.775, Loss:  0.277
# Epoch   2 Batch   31/134 - Train Accuracy:  0.763, Validation Accuracy:  0.776, Loss:  0.283
# Epoch   2 Batch   32/134 - Train Accuracy:  0.776, Validation Accuracy:  0.775, Loss:  0.273
# Epoch   2 Batch   33/134 - Train Accuracy:  0.757, Validation Accuracy:  0.770, Loss:  0.285
# Epoch   2 Batch   34/134 - Train Accuracy:  0.773, Validation Accuracy:  0.779, Loss:  0.290
# Epoch   2 Batch   35/134 - Train Accuracy:  0.778, Validation Accuracy:  0.776, Loss:  0.270
# Epoch   2 Batch   36/134 - Train Accuracy:  0.767, Validation Accuracy:  0.781, Loss:  0.273
# Epoch   2 Batch   37/134 - Train Accuracy:  0.772, Validation Accuracy:  0.779, Loss:  0.276
# Epoch   2 Batch   38/134 - Train Accuracy:  0.773, Validation Accuracy:  0.779, Loss:  0.272
# Epoch   2 Batch   39/134 - Train Accuracy:  0.774, Validation Accuracy:  0.792, Loss:  0.264
# Epoch   2 Batch   40/134 - Train Accuracy:  0.786, Validation Accuracy:  0.791, Loss:  0.267
# Epoch   2 Batch   41/134 - Train Accuracy:  0.774, Validation Accuracy:  0.787, Loss:  0.269
# Epoch   2 Batch   42/134 - Train Accuracy:  0.764, Validation Accuracy:  0.773, Loss:  0.264
# Epoch   2 Batch   43/134 - Train Accuracy:  0.770, Validation Accuracy:  0.784, Loss:  0.264
# Epoch   2 Batch   44/134 - Train Accuracy:  0.789, Validation Accuracy:  0.792, Loss:  0.255
# Epoch   2 Batch   45/134 - Train Accuracy:  0.791, Validation Accuracy:  0.788, Loss:  0.250
# Epoch   2 Batch   46/134 - Train Accuracy:  0.781, Validation Accuracy:  0.793, Loss:  0.250
# Epoch   2 Batch   47/134 - Train Accuracy:  0.779, Validation Accuracy:  0.798, Loss:  0.253
# Epoch   2 Batch   48/134 - Train Accuracy:  0.785, Validation Accuracy:  0.796, Loss:  0.251
# Epoch   2 Batch   49/134 - Train Accuracy:  0.795, Validation Accuracy:  0.799, Loss:  0.247
# Epoch   2 Batch   50/134 - Train Accuracy:  0.778, Validation Accuracy:  0.794, Loss:  0.251
# Epoch   2 Batch   51/134 - Train Accuracy:  0.783, Validation Accuracy:  0.791, Loss:  0.252
# Epoch   2 Batch   52/134 - Train Accuracy:  0.776, Validation Accuracy:  0.793, Loss:  0.242
# Epoch   2 Batch   53/134 - Train Accuracy:  0.777, Validation Accuracy:  0.796, Loss:  0.242
# Epoch   2 Batch   54/134 - Train Accuracy:  0.774, Validation Accuracy:  0.803, Loss:  0.240
# Epoch   2 Batch   55/134 - Train Accuracy:  0.790, Validation Accuracy:  0.801, Loss:  0.240
# Epoch   2 Batch   56/134 - Train Accuracy:  0.806, Validation Accuracy:  0.805, Loss:  0.230
# Epoch   2 Batch   57/134 - Train Accuracy:  0.802, Validation Accuracy:  0.803, Loss:  0.237
# Epoch   2 Batch   58/134 - Train Accuracy:  0.801, Validation Accuracy:  0.794, Loss:  0.231
# Epoch   2 Batch   59/134 - Train Accuracy:  0.780, Validation Accuracy:  0.798, Loss:  0.246
# Epoch   2 Batch   60/134 - Train Accuracy:  0.800, Validation Accuracy:  0.801, Loss:  0.226
# Epoch   2 Batch   61/134 - Train Accuracy:  0.803, Validation Accuracy:  0.798, Loss:  0.226
# Epoch   2 Batch   62/134 - Train Accuracy:  0.791, Validation Accuracy:  0.801, Loss:  0.230
# Epoch   2 Batch   63/134 - Train Accuracy:  0.803, Validation Accuracy:  0.808, Loss:  0.224
# Epoch   2 Batch   64/134 - Train Accuracy:  0.795, Validation Accuracy:  0.817, Loss:  0.231
# Epoch   2 Batch   65/134 - Train Accuracy:  0.790, Validation Accuracy:  0.806, Loss:  0.225
# Epoch   2 Batch   66/134 - Train Accuracy:  0.807, Validation Accuracy:  0.806, Loss:  0.220
# Epoch   2 Batch   67/134 - Train Accuracy:  0.778, Validation Accuracy:  0.809, Loss:  0.240
# Epoch   2 Batch   68/134 - Train Accuracy:  0.798, Validation Accuracy:  0.820, Loss:  0.229
# Epoch   2 Batch   69/134 - Train Accuracy:  0.810, Validation Accuracy:  0.820, Loss:  0.215
# Epoch   2 Batch   70/134 - Train Accuracy:  0.814, Validation Accuracy:  0.821, Loss:  0.215
# Epoch   2 Batch   71/134 - Train Accuracy:  0.814, Validation Accuracy:  0.818, Loss:  0.210
# Epoch   2 Batch   72/134 - Train Accuracy:  0.801, Validation Accuracy:  0.813, Loss:  0.211
# Epoch   2 Batch   73/134 - Train Accuracy:  0.806, Validation Accuracy:  0.814, Loss:  0.208
# Epoch   2 Batch   74/134 - Train Accuracy:  0.815, Validation Accuracy:  0.819, Loss:  0.212
# Epoch   2 Batch   75/134 - Train Accuracy:  0.818, Validation Accuracy:  0.824, Loss:  0.200
# Epoch   2 Batch   76/134 - Train Accuracy:  0.817, Validation Accuracy:  0.832, Loss:  0.207
# Epoch   2 Batch   77/134 - Train Accuracy:  0.828, Validation Accuracy:  0.829, Loss:  0.192
# Epoch   2 Batch   78/134 - Train Accuracy:  0.812, Validation Accuracy:  0.833, Loss:  0.201
# Epoch   2 Batch   79/134 - Train Accuracy:  0.815, Validation Accuracy:  0.829, Loss:  0.202
# Epoch   2 Batch   80/134 - Train Accuracy:  0.827, Validation Accuracy:  0.827, Loss:  0.195
# Epoch   2 Batch   81/134 - Train Accuracy:  0.819, Validation Accuracy:  0.830, Loss:  0.200
# Epoch   2 Batch   82/134 - Train Accuracy:  0.844, Validation Accuracy:  0.826, Loss:  0.185
# Epoch   2 Batch   83/134 - Train Accuracy:  0.818, Validation Accuracy:  0.834, Loss:  0.197
# Epoch   2 Batch   84/134 - Train Accuracy:  0.821, Validation Accuracy:  0.834, Loss:  0.192
# Epoch   2 Batch   85/134 - Train Accuracy:  0.834, Validation Accuracy:  0.829, Loss:  0.189
# Epoch   2 Batch   86/134 - Train Accuracy:  0.824, Validation Accuracy:  0.837, Loss:  0.184
# Epoch   2 Batch   87/134 - Train Accuracy:  0.810, Validation Accuracy:  0.842, Loss:  0.196
# Epoch   2 Batch   88/134 - Train Accuracy:  0.842, Validation Accuracy:  0.846, Loss:  0.176
# Epoch   2 Batch   89/134 - Train Accuracy:  0.831, Validation Accuracy:  0.844, Loss:  0.179
# Epoch   2 Batch   90/134 - Train Accuracy:  0.835, Validation Accuracy:  0.850, Loss:  0.184
# Epoch   2 Batch   91/134 - Train Accuracy:  0.856, Validation Accuracy:  0.839, Loss:  0.155
# Epoch   2 Batch   92/134 - Train Accuracy:  0.841, Validation Accuracy:  0.840, Loss:  0.175
# Epoch   2 Batch   93/134 - Train Accuracy:  0.847, Validation Accuracy:  0.842, Loss:  0.169
# Epoch   2 Batch   94/134 - Train Accuracy:  0.840, Validation Accuracy:  0.850, Loss:  0.175
# Epoch   2 Batch   95/134 - Train Accuracy:  0.828, Validation Accuracy:  0.847, Loss:  0.177
# Epoch   2 Batch   96/134 - Train Accuracy:  0.844, Validation Accuracy:  0.850, Loss:  0.175
# Epoch   2 Batch   97/134 - Train Accuracy:  0.821, Validation Accuracy:  0.849, Loss:  0.168
# Epoch   2 Batch   98/134 - Train Accuracy:  0.833, Validation Accuracy:  0.850, Loss:  0.183
# Epoch   2 Batch   99/134 - Train Accuracy:  0.841, Validation Accuracy:  0.850, Loss:  0.170
# Epoch   2 Batch  100/134 - Train Accuracy:  0.824, Validation Accuracy:  0.840, Loss:  0.165
# Epoch   2 Batch  101/134 - Train Accuracy:  0.841, Validation Accuracy:  0.841, Loss:  0.173
# Epoch   2 Batch  102/134 - Train Accuracy:  0.833, Validation Accuracy:  0.850, Loss:  0.170
# Epoch   2 Batch  103/134 - Train Accuracy:  0.851, Validation Accuracy:  0.850, Loss:  0.155
# Epoch   2 Batch  104/134 - Train Accuracy:  0.857, Validation Accuracy:  0.852, Loss:  0.158
# Epoch   2 Batch  105/134 - Train Accuracy:  0.857, Validation Accuracy:  0.865, Loss:  0.162
# Epoch   2 Batch  106/134 - Train Accuracy:  0.853, Validation Accuracy:  0.864, Loss:  0.155
# Epoch   2 Batch  107/134 - Train Accuracy:  0.864, Validation Accuracy:  0.868, Loss:  0.156
# Epoch   2 Batch  108/134 - Train Accuracy:  0.844, Validation Accuracy:  0.862, Loss:  0.159
# Epoch   2 Batch  109/134 - Train Accuracy:  0.871, Validation Accuracy:  0.864, Loss:  0.146
# Epoch   2 Batch  110/134 - Train Accuracy:  0.866, Validation Accuracy:  0.858, Loss:  0.147
# Epoch   2 Batch  111/134 - Train Accuracy:  0.849, Validation Accuracy:  0.862, Loss:  0.150
# Epoch   2 Batch  112/134 - Train Accuracy:  0.860, Validation Accuracy:  0.866, Loss:  0.147
# Epoch   2 Batch  113/134 - Train Accuracy:  0.874, Validation Accuracy:  0.857, Loss:  0.135
# Epoch   2 Batch  114/134 - Train Accuracy:  0.849, Validation Accuracy:  0.864, Loss:  0.146
# Epoch   2 Batch  115/134 - Train Accuracy:  0.849, Validation Accuracy:  0.866, Loss:  0.145
# Epoch   2 Batch  116/134 - Train Accuracy:  0.865, Validation Accuracy:  0.864, Loss:  0.140
# Epoch   2 Batch  117/134 - Train Accuracy:  0.864, Validation Accuracy:  0.867, Loss:  0.135
# Epoch   2 Batch  118/134 - Train Accuracy:  0.871, Validation Accuracy:  0.876, Loss:  0.136
# Epoch   2 Batch  119/134 - Train Accuracy:  0.885, Validation Accuracy:  0.880, Loss:  0.125
# Epoch   2 Batch  120/134 - Train Accuracy:  0.866, Validation Accuracy:  0.875, Loss:  0.133
# Epoch   2 Batch  121/134 - Train Accuracy:  0.868, Validation Accuracy:  0.873, Loss:  0.129
# Epoch   2 Batch  122/134 - Train Accuracy:  0.862, Validation Accuracy:  0.875, Loss:  0.133
# Epoch   2 Batch  123/134 - Train Accuracy:  0.869, Validation Accuracy:  0.872, Loss:  0.123
# Epoch   2 Batch  124/134 - Train Accuracy:  0.891, Validation Accuracy:  0.874, Loss:  0.121
# Epoch   2 Batch  125/134 - Train Accuracy:  0.880, Validation Accuracy:  0.875, Loss:  0.120
# Epoch   2 Batch  126/134 - Train Accuracy:  0.858, Validation Accuracy:  0.886, Loss:  0.130
# Epoch   2 Batch  127/134 - Train Accuracy:  0.878, Validation Accuracy:  0.887, Loss:  0.123
# Epoch   2 Batch  128/134 - Train Accuracy:  0.853, Validation Accuracy:  0.882, Loss:  0.128
# Epoch   2 Batch  129/134 - Train Accuracy:  0.860, Validation Accuracy:  0.880, Loss:  0.125
# Epoch   2 Batch  130/134 - Train Accuracy:  0.877, Validation Accuracy:  0.884, Loss:  0.121
# Epoch   2 Batch  131/134 - Train Accuracy:  0.870, Validation Accuracy:  0.883, Loss:  0.128
# Epoch   2 Batch  132/134 - Train Accuracy:  0.885, Validation Accuracy:  0.885, Loss:  0.117
# Epoch   3 Batch    0/134 - Train Accuracy:  0.883, Validation Accuracy:  0.890, Loss:  0.117
# Epoch   3 Batch    1/134 - Train Accuracy:  0.874, Validation Accuracy:  0.889, Loss:  0.116
# Epoch   3 Batch    2/134 - Train Accuracy:  0.892, Validation Accuracy:  0.884, Loss:  0.107
# Epoch   3 Batch    3/134 - Train Accuracy:  0.894, Validation Accuracy:  0.879, Loss:  0.112
# Epoch   3 Batch    4/134 - Train Accuracy:  0.877, Validation Accuracy:  0.884, Loss:  0.108
# Epoch   3 Batch    5/134 - Train Accuracy:  0.883, Validation Accuracy:  0.888, Loss:  0.116
# Epoch   3 Batch    6/134 - Train Accuracy:  0.888, Validation Accuracy:  0.885, Loss:  0.099
# Epoch   3 Batch    7/134 - Train Accuracy:  0.878, Validation Accuracy:  0.890, Loss:  0.108
# Epoch   3 Batch    8/134 - Train Accuracy:  0.880, Validation Accuracy:  0.880, Loss:  0.103
# Epoch   3 Batch    9/134 - Train Accuracy:  0.899, Validation Accuracy:  0.889, Loss:  0.098
# Epoch   3 Batch   10/134 - Train Accuracy:  0.880, Validation Accuracy:  0.886, Loss:  0.110
# Epoch   3 Batch   11/134 - Train Accuracy:  0.884, Validation Accuracy:  0.888, Loss:  0.105
# Epoch   3 Batch   12/134 - Train Accuracy:  0.891, Validation Accuracy:  0.890, Loss:  0.099
# Epoch   3 Batch   13/134 - Train Accuracy:  0.882, Validation Accuracy:  0.893, Loss:  0.105
# Epoch   3 Batch   14/134 - Train Accuracy:  0.884, Validation Accuracy:  0.895, Loss:  0.104
# Epoch   3 Batch   15/134 - Train Accuracy:  0.885, Validation Accuracy:  0.895, Loss:  0.101
# Epoch   3 Batch   16/134 - Train Accuracy:  0.890, Validation Accuracy:  0.894, Loss:  0.096
# Epoch   3 Batch   17/134 - Train Accuracy:  0.877, Validation Accuracy:  0.894, Loss:  0.103
# Epoch   3 Batch   18/134 - Train Accuracy:  0.882, Validation Accuracy:  0.895, Loss:  0.102
# Epoch   3 Batch   19/134 - Train Accuracy:  0.889, Validation Accuracy:  0.898, Loss:  0.093
# Epoch   3 Batch   20/134 - Train Accuracy:  0.900, Validation Accuracy:  0.902, Loss:  0.092
# Epoch   3 Batch   21/134 - Train Accuracy:  0.893, Validation Accuracy:  0.897, Loss:  0.097
# Epoch   3 Batch   22/134 - Train Accuracy:  0.887, Validation Accuracy:  0.895, Loss:  0.095
# Epoch   3 Batch   23/134 - Train Accuracy:  0.904, Validation Accuracy:  0.902, Loss:  0.087
# Epoch   3 Batch   24/134 - Train Accuracy:  0.889, Validation Accuracy:  0.904, Loss:  0.095
# Epoch   3 Batch   25/134 - Train Accuracy:  0.890, Validation Accuracy:  0.899, Loss:  0.085
# Epoch   3 Batch   26/134 - Train Accuracy:  0.893, Validation Accuracy:  0.904, Loss:  0.094
# Epoch   3 Batch   27/134 - Train Accuracy:  0.898, Validation Accuracy:  0.907, Loss:  0.090
# Epoch   3 Batch   28/134 - Train Accuracy:  0.890, Validation Accuracy:  0.907, Loss:  0.092
# Epoch   3 Batch   29/134 - Train Accuracy:  0.909, Validation Accuracy:  0.908, Loss:  0.080
# Epoch   3 Batch   30/134 - Train Accuracy:  0.894, Validation Accuracy:  0.905, Loss:  0.088
# Epoch   3 Batch   31/134 - Train Accuracy:  0.898, Validation Accuracy:  0.902, Loss:  0.088
# Epoch   3 Batch   32/134 - Train Accuracy:  0.902, Validation Accuracy:  0.903, Loss:  0.085
# Epoch   3 Batch   33/134 - Train Accuracy:  0.892, Validation Accuracy:  0.895, Loss:  0.090
# Epoch   3 Batch   34/134 - Train Accuracy:  0.897, Validation Accuracy:  0.908, Loss:  0.093
# Epoch   3 Batch   35/134 - Train Accuracy:  0.900, Validation Accuracy:  0.909, Loss:  0.088
# Epoch   3 Batch   36/134 - Train Accuracy:  0.904, Validation Accuracy:  0.909, Loss:  0.085
# Epoch   3 Batch   37/134 - Train Accuracy:  0.897, Validation Accuracy:  0.907, Loss:  0.085
# Epoch   3 Batch   38/134 - Train Accuracy:  0.902, Validation Accuracy:  0.906, Loss:  0.084
# Epoch   3 Batch   39/134 - Train Accuracy:  0.892, Validation Accuracy:  0.905, Loss:  0.082
# Epoch   3 Batch   40/134 - Train Accuracy:  0.896, Validation Accuracy:  0.909, Loss:  0.085
# Epoch   3 Batch   41/134 - Train Accuracy:  0.899, Validation Accuracy:  0.910, Loss:  0.084
# Epoch   3 Batch   42/134 - Train Accuracy:  0.900, Validation Accuracy:  0.908, Loss:  0.078
# Epoch   3 Batch   43/134 - Train Accuracy:  0.893, Validation Accuracy:  0.905, Loss:  0.085
# Epoch   3 Batch   44/134 - Train Accuracy:  0.912, Validation Accuracy:  0.902, Loss:  0.076
# Epoch   3 Batch   45/134 - Train Accuracy:  0.912, Validation Accuracy:  0.903, Loss:  0.075
# Epoch   3 Batch   46/134 - Train Accuracy:  0.903, Validation Accuracy:  0.909, Loss:  0.081
# Epoch   3 Batch   47/134 - Train Accuracy:  0.899, Validation Accuracy:  0.907, Loss:  0.076
# Epoch   3 Batch   48/134 - Train Accuracy:  0.915, Validation Accuracy:  0.910, Loss:  0.076
# Epoch   3 Batch   49/134 - Train Accuracy:  0.910, Validation Accuracy:  0.909, Loss:  0.074
# Epoch   3 Batch   50/134 - Train Accuracy:  0.904, Validation Accuracy:  0.906, Loss:  0.078
# Epoch   3 Batch   51/134 - Train Accuracy:  0.911, Validation Accuracy:  0.912, Loss:  0.080
# Epoch   3 Batch   52/134 - Train Accuracy:  0.907, Validation Accuracy:  0.917, Loss:  0.073
# Epoch   3 Batch   53/134 - Train Accuracy:  0.919, Validation Accuracy:  0.915, Loss:  0.074
# Epoch   3 Batch   54/134 - Train Accuracy:  0.897, Validation Accuracy:  0.914, Loss:  0.073
# Epoch   3 Batch   55/134 - Train Accuracy:  0.909, Validation Accuracy:  0.907, Loss:  0.074
# Epoch   3 Batch   56/134 - Train Accuracy:  0.909, Validation Accuracy:  0.912, Loss:  0.071
# Epoch   3 Batch   57/134 - Train Accuracy:  0.907, Validation Accuracy:  0.916, Loss:  0.072
# Epoch   3 Batch   58/134 - Train Accuracy:  0.908, Validation Accuracy:  0.919, Loss:  0.069
# Epoch   3 Batch   59/134 - Train Accuracy:  0.901, Validation Accuracy:  0.912, Loss:  0.075
# Epoch   3 Batch   60/134 - Train Accuracy:  0.910, Validation Accuracy:  0.914, Loss:  0.069
# Epoch   3 Batch   61/134 - Train Accuracy:  0.908, Validation Accuracy:  0.913, Loss:  0.068
# Epoch   3 Batch   62/134 - Train Accuracy:  0.915, Validation Accuracy:  0.914, Loss:  0.068
# Epoch   3 Batch   63/134 - Train Accuracy:  0.902, Validation Accuracy:  0.915, Loss:  0.068
# Epoch   3 Batch   64/134 - Train Accuracy:  0.907, Validation Accuracy:  0.920, Loss:  0.072
# Epoch   3 Batch   65/134 - Train Accuracy:  0.893, Validation Accuracy:  0.922, Loss:  0.073
# Epoch   3 Batch   66/134 - Train Accuracy:  0.907, Validation Accuracy:  0.921, Loss:  0.064
# Epoch   3 Batch   67/134 - Train Accuracy:  0.898, Validation Accuracy:  0.920, Loss:  0.072
# Epoch   3 Batch   68/134 - Train Accuracy:  0.907, Validation Accuracy:  0.920, Loss:  0.069
# Epoch   3 Batch   69/134 - Train Accuracy:  0.920, Validation Accuracy:  0.920, Loss:  0.065
# Epoch   3 Batch   70/134 - Train Accuracy:  0.911, Validation Accuracy:  0.918, Loss:  0.067
# Epoch   3 Batch   71/134 - Train Accuracy:  0.909, Validation Accuracy:  0.916, Loss:  0.064
# Epoch   3 Batch   72/134 - Train Accuracy:  0.912, Validation Accuracy:  0.920, Loss:  0.064
# Epoch   3 Batch   73/134 - Train Accuracy:  0.913, Validation Accuracy:  0.920, Loss:  0.069
# Epoch   3 Batch   74/134 - Train Accuracy:  0.916, Validation Accuracy:  0.915, Loss:  0.068
# Epoch   3 Batch   75/134 - Train Accuracy:  0.921, Validation Accuracy:  0.922, Loss:  0.064
# Epoch   3 Batch   76/134 - Train Accuracy:  0.925, Validation Accuracy:  0.924, Loss:  0.065
# Epoch   3 Batch   77/134 - Train Accuracy:  0.918, Validation Accuracy:  0.930, Loss:  0.061
# Epoch   3 Batch   78/134 - Train Accuracy:  0.916, Validation Accuracy:  0.930, Loss:  0.060
# Epoch   3 Batch   79/134 - Train Accuracy:  0.907, Validation Accuracy:  0.926, Loss:  0.065
# Epoch   3 Batch   80/134 - Train Accuracy:  0.922, Validation Accuracy:  0.926, Loss:  0.061
# Epoch   3 Batch   81/134 - Train Accuracy:  0.928, Validation Accuracy:  0.927, Loss:  0.064
# Epoch   3 Batch   82/134 - Train Accuracy:  0.922, Validation Accuracy:  0.923, Loss:  0.059
# Epoch   3 Batch   83/134 - Train Accuracy:  0.918, Validation Accuracy:  0.928, Loss:  0.065
# Epoch   3 Batch   84/134 - Train Accuracy:  0.911, Validation Accuracy:  0.928, Loss:  0.061
# Epoch   3 Batch   85/134 - Train Accuracy:  0.923, Validation Accuracy:  0.928, Loss:  0.062
# Epoch   3 Batch   86/134 - Train Accuracy:  0.921, Validation Accuracy:  0.932, Loss:  0.058
# Epoch   3 Batch   87/134 - Train Accuracy:  0.905, Validation Accuracy:  0.930, Loss:  0.067
# Epoch   3 Batch   88/134 - Train Accuracy:  0.927, Validation Accuracy:  0.927, Loss:  0.056
# Epoch   3 Batch   89/134 - Train Accuracy:  0.923, Validation Accuracy:  0.927, Loss:  0.057
# Epoch   3 Batch   90/134 - Train Accuracy:  0.923, Validation Accuracy:  0.927, Loss:  0.060
# Epoch   3 Batch   91/134 - Train Accuracy:  0.942, Validation Accuracy:  0.932, Loss:  0.046
# Epoch   3 Batch   92/134 - Train Accuracy:  0.927, Validation Accuracy:  0.932, Loss:  0.057
# Epoch   3 Batch   93/134 - Train Accuracy:  0.926, Validation Accuracy:  0.926, Loss:  0.053
# Epoch   3 Batch   94/134 - Train Accuracy:  0.928, Validation Accuracy:  0.927, Loss:  0.057
# Epoch   3 Batch   95/134 - Train Accuracy:  0.923, Validation Accuracy:  0.931, Loss:  0.059
# Epoch   3 Batch   96/134 - Train Accuracy:  0.922, Validation Accuracy:  0.930, Loss:  0.057
# Epoch   3 Batch   97/134 - Train Accuracy:  0.916, Validation Accuracy:  0.927, Loss:  0.055
# Epoch   3 Batch   98/134 - Train Accuracy:  0.914, Validation Accuracy:  0.935, Loss:  0.061
# Epoch   3 Batch   99/134 - Train Accuracy:  0.917, Validation Accuracy:  0.929, Loss:  0.058
# Epoch   3 Batch  100/134 - Train Accuracy:  0.925, Validation Accuracy:  0.924, Loss:  0.055
# Epoch   3 Batch  101/134 - Train Accuracy:  0.923, Validation Accuracy:  0.932, Loss:  0.058
# Epoch   3 Batch  102/134 - Train Accuracy:  0.911, Validation Accuracy:  0.935, Loss:  0.058
# Epoch   3 Batch  103/134 - Train Accuracy:  0.925, Validation Accuracy:  0.937, Loss:  0.055
# Epoch   3 Batch  104/134 - Train Accuracy:  0.927, Validation Accuracy:  0.934, Loss:  0.053
# Epoch   3 Batch  105/134 - Train Accuracy:  0.927, Validation Accuracy:  0.930, Loss:  0.058
# Epoch   3 Batch  106/134 - Train Accuracy:  0.922, Validation Accuracy:  0.930, Loss:  0.053
# Epoch   3 Batch  107/134 - Train Accuracy:  0.924, Validation Accuracy:  0.930, Loss:  0.058
# Epoch   3 Batch  108/134 - Train Accuracy:  0.925, Validation Accuracy:  0.937, Loss:  0.055
# Epoch   3 Batch  109/134 - Train Accuracy:  0.931, Validation Accuracy:  0.934, Loss:  0.052
# Epoch   3 Batch  110/134 - Train Accuracy:  0.933, Validation Accuracy:  0.931, Loss:  0.052
# Epoch   3 Batch  111/134 - Train Accuracy:  0.927, Validation Accuracy:  0.937, Loss:  0.055
# Epoch   3 Batch  112/134 - Train Accuracy:  0.925, Validation Accuracy:  0.938, Loss:  0.052
# Epoch   3 Batch  113/134 - Train Accuracy:  0.931, Validation Accuracy:  0.939, Loss:  0.053
# Epoch   3 Batch  114/134 - Train Accuracy:  0.928, Validation Accuracy:  0.937, Loss:  0.050
# Epoch   3 Batch  115/134 - Train Accuracy:  0.922, Validation Accuracy:  0.939, Loss:  0.052
# Epoch   3 Batch  116/134 - Train Accuracy:  0.930, Validation Accuracy:  0.926, Loss:  0.053
# Epoch   3 Batch  117/134 - Train Accuracy:  0.939, Validation Accuracy:  0.928, Loss:  0.046
# Epoch   3 Batch  118/134 - Train Accuracy:  0.934, Validation Accuracy:  0.934, Loss:  0.050
# Epoch   3 Batch  119/134 - Train Accuracy:  0.936, Validation Accuracy:  0.933, Loss:  0.045
# Epoch   3 Batch  120/134 - Train Accuracy:  0.924, Validation Accuracy:  0.932, Loss:  0.052
# Epoch   3 Batch  121/134 - Train Accuracy:  0.923, Validation Accuracy:  0.932, Loss:  0.048
# Epoch   3 Batch  122/134 - Train Accuracy:  0.923, Validation Accuracy:  0.936, Loss:  0.049
# Epoch   3 Batch  123/134 - Train Accuracy:  0.932, Validation Accuracy:  0.933, Loss:  0.046
# Epoch   3 Batch  124/134 - Train Accuracy:  0.940, Validation Accuracy:  0.937, Loss:  0.045
# Epoch   3 Batch  125/134 - Train Accuracy:  0.942, Validation Accuracy:  0.934, Loss:  0.042
# Epoch   3 Batch  126/134 - Train Accuracy:  0.924, Validation Accuracy:  0.936, Loss:  0.050
# Epoch   3 Batch  127/134 - Train Accuracy:  0.924, Validation Accuracy:  0.934, Loss:  0.046
# Epoch   3 Batch  128/134 - Train Accuracy:  0.920, Validation Accuracy:  0.938, Loss:  0.052
# Epoch   3 Batch  129/134 - Train Accuracy:  0.934, Validation Accuracy:  0.936, Loss:  0.047
# Epoch   3 Batch  130/134 - Train Accuracy:  0.932, Validation Accuracy:  0.942, Loss:  0.046
# Epoch   3 Batch  131/134 - Train Accuracy:  0.927, Validation Accuracy:  0.941, Loss:  0.049
# Epoch   3 Batch  132/134 - Train Accuracy:  0.931, Validation Accuracy:  0.943, Loss:  0.044
# Model Trained and Saved

# %% [markdown]
# ### 保存参数
#
# 保存 `batch_size` 和 `save_path` 参数以进行推论（for inference）。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # 检查点

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## 句子到序列
#
# 要向模型提供要翻译的句子，你首先需要预处理该句子。实现函数 `sentence_to_seq()` 以预处理新的句子。
#
# - 将句子转换为小写形式
# - 使用 `vocab_to_int` 将单词转换为 id
#  - 如果单词不在词汇表中，将其转换为`<UNK>` 单词 id

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    word_ids = []
    for word in sentence.split(' '):
        word = word.lower()
        if word not in vocab_to_int:
            word_ids.append(vocab_to_int['<UNK>'])
        else:
            word_ids.append(vocab_to_int[word])
    return word_ids

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## 翻译
#
# 将 `translate_sentence` 从英语翻译成法语。

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [189, 41, 107, 146, 161, 104, 151]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [73, 112, 71, 313, 331, 1]
#   French Words: ['il', 'conduit', 'un', 'brillant', '.', '<EOS>']

# %% [markdown]
# ## 不完美的翻译
#
# 你可能注意到了，某些句子的翻译质量比其他的要好。因为你使用的数据集只有 227 个英语单词，但实际生活中有数千个单词，只有使用这些单词的句子结果才会比较理想。对于此项目，不需要达到完美的翻译。但是，如果你想创建更好的翻译模型，则需要更好的数据。
#
# 你可以使用 [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar) 语料库训练模型。该数据集拥有更多的词汇，讨论的话题也更丰富。但是，训练时间要好多天的时间，所以确保你有 GPU 并且对于我们提供的数据集，你的神经网络性能很棒。提交此项目后，别忘了研究下 WMT10 语料库。
#
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。保存记事本文件为 “dlnd_language_translation.ipynb”，再通过菜单中的“文件” ->“下载为”将其另存为 HTML 格式。提交的项目文档中需包含“helper.py”和“problem_unittests.py”文件。
